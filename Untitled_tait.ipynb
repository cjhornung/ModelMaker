# %%
import pandas as pd
import random

# %%
backpacks = list(range(93, 103))
heads = list(range(73,93))
heads.append(137)
heads.append(138)
sergeant_heads=list(range(130,135))
sergeant_right_pauldrons=list(range(135,137))
left_pauldrons=list(range(113,123))
right_pauldrons=list(range(103,113))
torsos=list(range(9,19))
plasma_pistols=[8,30,16]
bolt_pistol=[7,29,15,23,36,44,50,56,64,72]
one_hand_weapon=[131,6,28,14,22,35,43,49,55,63,71]
two_hand_weapons_left_hand=[124,128]
two_hand_weapons_right_hand=[125,129]

# %%
#rules
#the model with backpack 96 must have a plasma pistol
#the sergeant model must also have a plasma pistol
#for each squad of 10, we must use all plasma pistols and all two handed weapons
#sergeant can use any left_pauldron but must have one of the sergeant_right_pauldrons [135,136] as his right pauldron 
#sergeants can be any of m,odels [9,11,14,15,18] 

#models [10,12,13,16,17] are limited to right_pauldrons [105,106,107,110,111]
#models [9,11,14,15,18] are limited to right_pauldrons [103,104,108,109,112] or [135,136] if they're a sergeant

# %%
squad_test_dict={}
count=1
while count<=9:

    # Add a new key-value pair to the dictionary
    squad_test_dict[count] = {
        "right_pauldron": right_pauldrons[random.randint(0, len(right_pauldrons)-1)],
        "left_pauldron": left_pauldrons[random.randint(0, len(left_pauldrons)-1)],
        "right_arm": bolt_pistol[random.randint(0, len(bolt_pistol)-1)],
        "left_arm": one_hand_weapon[random.randint(0, len(one_hand_weapon)-1)],
        "backpack":backpacks[random.randint(0, len(backpacks)-1)],
        "head": heads[random.randint(0, len(heads)-1)],
        "torso": torsos[random.randint(0, len(torsos)-1)]
    }

    if squad_test_dict[count]["backpack"]==96:
        squad_test_dict[count]["right_pauldron"] = sergeant_right_pauldrons[random.randint(0, len(sergeant_right_pauldrons)-1)]

    else:
        right_pauldrons.remove(squad_test_dict[count]["right_pauldron"]),
        bolt_pistol.remove(squad_test_dict[count]["right_arm"])

    if plasma_count < 1 or plasma_count > 1:
        squad_test_dict[count]["right_arm"]=plasma_pistols[random.randint (0, len(plasma_pistols)-1)]
        
    
    left_pauldrons.remove(squad_test_dict[count]["left_pauldron"])
    
    one_hand_weapon.remove(squad_test_dict[count]["left_arm"])
    backpacks.remove(squad_test_dict[count]["backpack"])
    heads.remove(squad_test_dict[count]["head"])

    # Increment the count variable
    count += 1
    plasma_count += 1


squad_test_dict
# Out:
# {1: {'right_pauldron': 136,
#   'left_pauldron': 118,
#   'right_arm': 56,
#   'left_arm': 14,
#   'backpack': 96,
#   'head': 75,
#   'torso': 13},
#  2: {'right_pauldron': 105,
#   'left_pauldron': 117,
#   'right_arm': 50,
#   'left_arm': 35,
#   'backpack': 100,
#   'head': 77,
#   'torso': 11},
#  3: {'right_pauldron': 110,
#   'left_pauldron': 119,
#   'right_arm': 36,
#   'left_arm': 71,
#   'backpack': 95,
#   'head': 81,
#   'torso': 10},
#  4: {'right_pauldron': 103,
#   'left_pauldron': 121,
#   'right_arm': 15,
#   'left_arm': 22,
#   'backpack': 93,
#   'head': 78,
#   'torso': 11},
#  5: {'right_pauldron': 106,
#   'left_pauldron': 116,
#   'right_arm': 29,
#   'left_arm': 55,
#   'backpack': 94,
#   'head': 138,
#   'torso': 13},
#  6: {'right_pauldron': 112,
#   'left_pauldron': 120,
#   'right_arm': 7,
#   'left_arm': 49,
#   'backpack': 102,
#   'head': 74,
#   'torso': 18},
#  7: {'right_pauldron': 104,
#   'left_pauldron': 115,
#   'right_arm': 64,
#   'left_arm': 131,
#   'backpack': 101,
#   'head': 90,
#   'torso': 10},
#  8: {'right_pauldron': 107,
#   'left_pauldron': 122,
#   'right_arm': 44,
#   'left_arm': 28,
#   'backpack': 97,
#   'head': 82,
#   'torso': 14},
#  9: {'right_pauldron': 108,
#   'left_pauldron': 114,
#   'right_arm': 72,
#   'left_arm': 63,
#   'backpack': 98,
#   'head': 85,
#   'torso': 11}}

# %%
#this is the first squad and also the skeleton for future loadouts
squad_1 = {
    "Model 9": {
        "right_pauldron": "135",
        "left_pauldron": "118",
        "backpack":"93", 
        "head": "130"
    },
    "Model 10": {
        "right_pauldron": "110",
        "left_pauldron": "117",
        "backpack":"96",
        "head": "75"
    },
    "Model 11": {
        "right_pauldron": "103",
        "left_pauldron": "119",
        "backpack":"95",
        "head": "76"
    },
    "Model 12": {
        "right_pauldron": "106",
        "left_pauldron": "116",
        "backpack":"94",
        "head": "74"
    },
    "Model 13": {
        "right_pauldron": "107",
        "left_pauldron": "121",
        "backpack":"97",
        "head": "77"
    },
    "Model 14": {
        "right_pauldron": "108",
        "left_pauldron": "113",
        "backpack":"98",
        "head": "78"
    },
    "Model 15": {
        "right_pauldron": "109",
        "left_pauldron": "120",
        "backpack":"99",
        "head": "79"
    },
    "Model 16": {
        "right_pauldron": "110",
        "left_pauldron": "114",
        "backpack":"100",
        "head": "80"
    },
    "Model 17": {
        "right_pauldron": "111",
        "left_pauldron": "115",
        "backpack":"101",
        "head": "73"
    },
    "Model 18": {
        "right_pauldron": "112",
        "left_pauldron": "122",
        "backpack":"102",
        "head": "81"
    }
}

# %%
# Dictionaries

{1: {'right_pauldron': 111,
  'left_pauldron': 116,
  'right_arm': 72,
  'left_arm': 71,
  'backpack': 94,
  'head': 86,
  'torso': 9},
 2: {'right_pauldron': 107,
  'left_pauldron': 114,
  'right_arm': 15,
  'left_arm': 6,
  'backpack': 101,
  'head': 84,
  'torso': 16},
 3: {'right_pauldron': 110,
  'left_pauldron': 121,
  'right_arm': 23,
  'left_arm': 49,
  'backpack': 100,
  'head': 85,
  'torso': 16},
 4: {'right_pauldron': 109,
  'left_pauldron': 115,
  'right_arm': 36,
  'left_arm': 22,
  'backpack': 93,
  'head': 91,
  'torso': 9},
 5: {'right_pauldron': 105,
  'left_pauldron': 118,
  'right_arm': 29,
  'left_arm': 55,
  'backpack': 102,
  'head': 75,
  'torso': 16},
 6: {'right_pauldron': 112,
  'left_pauldron': 122,
  'right_arm': 64,
  'left_arm': 63,
  'backpack': 95,
  'head': 81,
  'torso': 18},
 7: {'right_pauldron': 108,
  'left_pauldron': 120,
  'right_arm': 50,
  'left_arm': 28,
  'backpack': 98,
  'head': 74,
  'torso': 9},
 8: {'right_pauldron': 104,
  'left_pauldron': 117,
  'right_arm': 56,
  'left_arm': 35,
  'backpack': 99,
  'head': 87,
  'torso': 13},
 9: {'right_pauldron': 103,
  'left_pauldron': 119,
  'right_arm': 7,
  'left_arm': 14,
  'backpack': 97,
  'head': 137,
  'torso': 15}}

{1: {'right_pauldron': 106,
  'left_pauldron': 115,
  'right_arm': 36,
  'left_arm': 49,
  'backpack': 99,
  'head': 81,
  'torso': 16},
 2: {'right_pauldron': 103,
  'left_pauldron': 114,
  'right_arm': 56,
  'left_arm': 131,
  'backpack': 101,
  'head': 91,
  'torso': 17},
 3: {'right_pauldron': 109,
  'left_pauldron': 113,
  'right_arm': 15,
  'left_arm': 35,
  'backpack': 95,
  'head': 82,
  'torso': 18},
 4: {'right_pauldron': 111,
  'left_pauldron': 116,
  'right_arm': 50,
  'left_arm': 14,
  'backpack': 98,
  'head': 76,
  'torso': 15},
 5: {'right_pauldron': 107,
  'left_pauldron': 118,
  'right_arm': 44,
  'left_arm': 71,
  'backpack': 93,
  'head': 87,
  'torso': 11},
 6: {'right_pauldron': 110,
  'left_pauldron': 122,
  'right_arm': 72,
  'left_arm': 63,
  'backpack': 94,
  'head': 85,
  'torso': 11},
 7: {'right_pauldron': 105,
  'left_pauldron': 119,
  'right_arm': 29,
  'left_arm': 43,
  'backpack': 100,
  'head': 137,
  'torso': 10},
 8: {'right_pauldron': 112,
  'left_pauldron': 120,
  'right_arm': 23,
  'left_arm': 28,
  'backpack': 97,
  'head': 88,
  'torso': 13},
 9: {'right_pauldron': 108,
  'left_pauldron': 121,
  'right_arm': 64,
  'left_arm': 6,
  'backpack': 102,
  'head': 73,
  'torso': 15}}

{1: {'right_pauldron': 103,
  'left_pauldron': 118,
  'right_arm': 56,
  'left_arm': 71,
  'backpack': 98,
  'head': 80,
  'torso': 15},
 2: {'right_pauldron': 111,
  'left_pauldron': 121,
  'right_arm': 7,
  'left_arm': 49,
  'backpack': 93,
  'head': 84,
  'torso': 15},
 3: {'right_pauldron': 112,
  'left_pauldron': 119,
  'right_arm': 44,
  'left_arm': 14,
  'backpack': 97,
  'head': 87,
  'torso': 17},
 4: {'right_pauldron': 110,
  'left_pauldron': 115,
  'right_arm': 36,
  'left_arm': 28,
  'backpack': 99,
  'head': 92,
  'torso': 12},
 5: {'right_pauldron': 106,
  'left_pauldron': 114,
  'right_arm': 64,
  'left_arm': 131,
  'backpack': 94,
  'head': 74,
  'torso': 10},
 6: {'right_pauldron': 108,
  'left_pauldron': 122,
  'right_arm': 72,
  'left_arm': 55,
  'backpack': 102,
  'head': 77,
  'torso': 11},
 7: {'right_pauldron': 109,
  'left_pauldron': 116,
  'right_arm': 29,
  'left_arm': 43,
  'backpack': 101,
  'head': 85,
  'torso': 12},
 8: {'right_pauldron': 105,
  'left_pauldron': 120,
  'right_arm': 50,
  'left_arm': 22,
  'backpack': 100,
  'head': 73,
  'torso': 17},
 9: {'right_pauldron': 104,
  'left_pauldron': 117,
  'right_arm': 15,
  'left_arm': 6,
  'backpack': 95,
  'head': 76,
  'torso': 11}}

{1: {'right_pauldron': 103,
  'left_pauldron': 113,
  'right_arm': 44,
  'left_arm': 71,
  'backpack': 101,
  'head': 88,
  'torso': 13},
 2: {'right_pauldron': 107,
  'left_pauldron': 116,
  'right_arm': 23,
  'left_arm': 22,
  'backpack': 97,
  'head': 137,
  'torso': 18},
 3: {'right_pauldron': 110,
  'left_pauldron': 122,
  'right_arm': 15,
  'left_arm': 131,
  'backpack': 100,
  'head': 138,
  'torso': 15},
 4: {'right_pauldron': 106,
  'left_pauldron': 118,
  'right_arm': 56,
  'left_arm': 28,
  'backpack': 94,
  'head': 92,
  'torso': 10},
 5: {'right_pauldron': 104,
  'left_pauldron': 119,
  'right_arm': 7,
  'left_arm': 43,
  'backpack': 99,
  'head': 79,
  'torso': 10},
 6: {'right_pauldron': 111,
  'left_pauldron': 121,
  'right_arm': 36,
  'left_arm': 55,
  'backpack': 93,
  'head': 73,
  'torso': 14},
 7: {'right_pauldron': 112,
  'left_pauldron': 120,
  'right_arm': 72,
  'left_arm': 49,
  'backpack': 95,
  'head': 86,
  'torso': 11},
 8: {'right_pauldron': 105,
  'left_pauldron': 114,
  'right_arm': 64,
  'left_arm': 6,
  'backpack': 98,
  'head': 85,
  'torso': 11},
 9: {'right_pauldron': 109,
  'left_pauldron': 115,
  'right_arm': 29,
  'left_arm': 14,
  'backpack': 102,
  'head': 75,
  'torso': 10}}
